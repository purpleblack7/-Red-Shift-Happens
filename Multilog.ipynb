# %%
import pandas as pd
import numpy as np
# %load_ext rpy2.ipython

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%R
# data = read.csv("/content/drive/MyDrive/BUDT758B/Data/cleaned_datafinal.csv", encoding = 'utf-8')

# %%
# %%R
# install.packages("tidyverse")
# library(tidyverse)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/tidyverse_1.3.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 702779 bytes (686 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# require("tidyverse")
# require("xgboost")
# require("tidymodels")
# Out:
# R[write to console]: Loading required package: xgboost
#
# R[write to console]: Loading required package: tidymodels

# %%
# %%R
# data$decade = as.factor(data$decade)

# %%
# %%R
# data <- data %>%
#   select(-c(name, release_date, is_popular, year, popularity, id_artists, X, artist1, artist2, artist3, artist4))

# %%
# %%R
# df_split <- initial_split(data)
# df_train <- training(df_split)
# df_test <- testing(df_split)
# Out:
# R[write to console]: Error in initial_split(data) : could not find function "initial_split"
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE,  :
# R[write to console]:
#
# R[write to console]:  there is no package called ‘xgboost’
#
# R[write to console]: 2:
# R[write to console]: In library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE,  :
# R[write to console]:
#
# R[write to console]:  there is no package called ‘tidymodels’
# Error in initial_split(data) : could not find function "initial_split"

# %%
# %%R
# logistic_model <- multinom_reg() %>%
#   set_engine("glmnet") %>%
#   set_mode("classification")
#
# log_one <- logistic_model %>%
#   fit(decade ~ ., data=df_train)
#
# log_one
# Out:
# R[write to console]: Error in set_mode(., "classification") :
#   could not find function "set_mode"
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In system("timedatectl", intern = TRUE) :
# R[write to console]:
#
# R[write to console]:  running command 'timedatectl' had status 1
# Error in set_mode(., "classification") :
#   could not find function "set_mode"

# %%
log_model <- multinom_reg() %>% 
  set_engine("glmnet") %>% 
  set_mode("classification") %>% 
  translate()

log_two <- log_model %>% 
  fit(decade ~ ., data=df_train)
```
